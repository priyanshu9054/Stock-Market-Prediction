# %%
import pandas as pd
df=pd.read_csv('MSFT.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060163  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062311   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063386   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061774    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060700    47894400

# %%
df=df[['Date','Close']]
df.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9619 entries, 0 to 9618
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9619 non-null   object
#  1   Close   9619 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 150.4+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9619 entries, 0 to 9618
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9619 non-null   datetime64[ns]
#  1   Close   9619 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 150.4 KB

# %%
df.index=df.pop('Date')
df.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.array(df.index),np.array(df['Close']))

# %%
import numpy as np
import datetime

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = pd.to_datetime(first_date_str)
  last_date  = pd.to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 84053.5469 - mean_absolute_error: 288.1422 - val_loss: 92614.2188 - val_mean_absolute_error: 304.2388
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 84510.0156 - mean_absolute_error: 289.0007 - val_loss: 92357.1719 - val_mean_absolute_error: 303.8161
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 84399.1875 - mean_absolute_error: 288.8224 - val_loss: 92238.0469 - val_mean_absolute_error: 303.6200
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 84747.4766 - mean_absolute_error: 289.4172 - val_loss: 92067.7734 - val_mean_absolute_error: 303.3394
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 84465.4141 - mean_absolute_error: 288.9524 - val_loss: 91750.3203 - val_mean_absolute_error: 302.8157
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83622.7578 - mean_absolute_error: 287.4345 - val_loss: 91336.5625 - val_mean_absolute_error: 302.1317
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 83783.8672 - mean_absolute_error: 287.7819 - val_loss: 90756.7188 - val_mean_absolute_error: 301.1707
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 82891.2812 - mean_absolute_error: 286.0216 - val_loss: 90123.5000 - val_mean_absolute_error: 300.1175
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82464.9219 - mean_absolute_error: 285.3879 - val_loss: 89259.0781 - val_mean_absolute_error: 298.6737
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 81803.7422 - mean_absolute_error: 284.3017 - val_loss: 87613.1406 - val_mean_absolute_error: 295.9056
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 79971.7969 - mean_absolute_error: 280.9986 - val_loss: 85830.4375 - val_mean_absolute_error: 292.8779
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 78326.5078 - mean_absolute_error: 277.9796 - val_loss: 84036.1797 - val_mean_absolute_error: 289.7985
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 75861.7734 - mean_absolute_error: 273.6144 - val_loss: 81615.7734 - val_mean_absolute_error: 285.5917
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 74490.3047 - mean_absolute_error: 271.0159 - val_loss: 77828.8984 - val_mean_absolute_error: 278.8833
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70859.4844 - mean_absolute_error: 264.2645 - val_loss: 74292.8594 - val_mean_absolute_error: 272.4698
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 66245.4062 - mean_absolute_error: 255.3485 - val_loss: 69978.3828 - val_mean_absolute_error: 264.4340
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 61724.4883 - mean_absolute_error: 246.4529 - val_loss: 65110.0547 - val_mean_absolute_error: 255.0629
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 57891.5547 - mean_absolute_error: 238.5120 - val_loss: 59595.3008 - val_mean_absolute_error: 244.0125
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 51928.0977 - mean_absolute_error: 225.6393 - val_loss: 53736.4219 - val_mean_absolute_error: 231.6969
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 46980.9102 - mean_absolute_error: 214.3930 - val_loss: 47577.0664 - val_mean_absolute_error: 217.9999
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40387.0586 - mean_absolute_error: 198.4409 - val_loss: 40878.9219 - val_mean_absolute_error: 202.0544
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34636.2891 - mean_absolute_error: 183.2347 - val_loss: 34639.0938 - val_mean_absolute_error: 185.9734
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28891.0371 - mean_absolute_error: 166.9532 - val_loss: 28577.4180 - val_mean_absolute_error: 168.8918
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23291.2773 - mean_absolute_error: 149.2482 - val_loss: 22863.4824 - val_mean_absolute_error: 151.0315
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19060.3633 - mean_absolute_error: 134.2388 - val_loss: 17621.1777 - val_mean_absolute_error: 132.5445
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13948.7109 - mean_absolute_error: 113.3629 - val_loss: 12813.9629 - val_mean_absolute_error: 112.9639
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9635.8105 - mean_absolute_error: 92.9778 - val_loss: 8573.0840 - val_mean_absolute_error: 92.3041
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6062.4941 - mean_absolute_error: 71.3908 - val_loss: 5691.7036 - val_mean_absolute_error: 75.0915
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4212.0015 - mean_absolute_error: 56.1703 - val_loss: 3590.8818 - val_mean_absolute_error: 59.4803
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2722.2646 - mean_absolute_error: 41.9182 - val_loss: 2121.4377 - val_mean_absolute_error: 45.4765
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1798.5450 - mean_absolute_error: 34.6549 - val_loss: 979.0818 - val_mean_absolute_error: 30.4319
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1207.5408 - mean_absolute_error: 29.5430 - val_loss: 526.2236 - val_mean_absolute_error: 21.7584
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1025.4774 - mean_absolute_error: 27.4757 - val_loss: 311.4340 - val_mean_absolute_error: 16.0787
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1026.3242 - mean_absolute_error: 27.0561 - val_loss: 213.3666 - val_mean_absolute_error: 12.9097
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1076.3984 - mean_absolute_error: 28.0809 - val_loss: 184.1796 - val_mean_absolute_error: 11.7964
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 962.6932 - mean_absolute_error: 25.5665 - val_loss: 201.2679 - val_mean_absolute_error: 12.4616
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1012.2654 - mean_absolute_error: 26.8415 - val_loss: 224.8414 - val_mean_absolute_error: 13.3192
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 989.5574 - mean_absolute_error: 26.5916 - val_loss: 230.9702 - val_mean_absolute_error: 13.5324
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1037.2711 - mean_absolute_error: 27.2299 - val_loss: 241.6247 - val_mean_absolute_error: 13.8944
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1042.7557 - mean_absolute_error: 27.4266 - val_loss: 258.7759 - val_mean_absolute_error: 14.4563
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 991.3894 - mean_absolute_error: 26.4246 - val_loss: 270.9766 - val_mean_absolute_error: 14.8419
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1000.7150 - mean_absolute_error: 26.5892 - val_loss: 285.1958 - val_mean_absolute_error: 15.2779
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1037.2126 - mean_absolute_error: 27.0979 - val_loss: 287.9266 - val_mean_absolute_error: 15.3602
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1007.5980 - mean_absolute_error: 26.6930 - val_loss: 276.1508 - val_mean_absolute_error: 15.0023
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1095.2002 - mean_absolute_error: 28.3655 - val_loss: 287.1270 - val_mean_absolute_error: 15.3365
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1009.6359 - mean_absolute_error: 27.0807 - val_loss: 295.5284 - val_mean_absolute_error: 15.5884
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 997.4270 - mean_absolute_error: 26.9329 - val_loss: 380.6041 - val_mean_absolute_error: 18.1325
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1003.8983 - mean_absolute_error: 26.9976 - val_loss: 298.5139 - val_mean_absolute_error: 15.7122
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 979.8809 - mean_absolute_error: 26.4015 - val_loss: 307.3869 - val_mean_absolute_error: 16.0228
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1014.2073 - mean_absolute_error: 27.2824 - val_loss: 314.9633 - val_mean_absolute_error: 16.2597
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 982.3864 - mean_absolute_error: 26.9963 - val_loss: 288.2973 - val_mean_absolute_error: 15.4601
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 849.1141 - mean_absolute_error: 24.3694 - val_loss: 253.4631 - val_mean_absolute_error: 14.4092
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 772.6808 - mean_absolute_error: 23.3193 - val_loss: 186.8928 - val_mean_absolute_error: 12.0583
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 695.8884 - mean_absolute_error: 21.8825 - val_loss: 170.7489 - val_mean_absolute_error: 11.4584
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 722.7312 - mean_absolute_error: 22.5769 - val_loss: 211.0905 - val_mean_absolute_error: 13.0683
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 630.9431 - mean_absolute_error: 21.1057 - val_loss: 287.7814 - val_mean_absolute_error: 15.7488
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 608.1750 - mean_absolute_error: 20.7425 - val_loss: 317.2008 - val_mean_absolute_error: 16.7046
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 589.6598 - mean_absolute_error: 20.3523 - val_loss: 551.8743 - val_mean_absolute_error: 22.7053
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 585.4374 - mean_absolute_error: 19.8523 - val_loss: 214.0990 - val_mean_absolute_error: 13.2338
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 492.6072 - mean_absolute_error: 18.1981 - val_loss: 160.5121 - val_mean_absolute_error: 11.2687
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 464.5592 - mean_absolute_error: 17.9769 - val_loss: 59.5320 - val_mean_absolute_error: 6.1345
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 450.0929 - mean_absolute_error: 18.2949 - val_loss: 48.1361 - val_mean_absolute_error: 5.4368
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 443.5449 - mean_absolute_error: 17.8163 - val_loss: 70.2461 - val_mean_absolute_error: 6.7814
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 353.3060 - mean_absolute_error: 15.6704 - val_loss: 150.8245 - val_mean_absolute_error: 10.9389
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 361.5897 - mean_absolute_error: 15.7256 - val_loss: 49.7114 - val_mean_absolute_error: 5.5932
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 280.9485 - mean_absolute_error: 13.7987 - val_loss: 63.2501 - val_mean_absolute_error: 6.4741
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 279.1655 - mean_absolute_error: 14.0939 - val_loss: 91.1972 - val_mean_absolute_error: 8.0821
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 251.2769 - mean_absolute_error: 13.0627 - val_loss: 133.7334 - val_mean_absolute_error: 10.1948
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 217.4891 - mean_absolute_error: 12.0701 - val_loss: 82.5744 - val_mean_absolute_error: 7.6100
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 194.9047 - mean_absolute_error: 11.3353 - val_loss: 95.4090 - val_mean_absolute_error: 8.2977
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 174.3178 - mean_absolute_error: 10.5488 - val_loss: 60.3239 - val_mean_absolute_error: 6.4501
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 150.2815 - mean_absolute_error: 9.7360 - val_loss: 62.6945 - val_mean_absolute_error: 6.6224
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 123.4522 - mean_absolute_error: 8.9304 - val_loss: 33.6253 - val_mean_absolute_error: 5.0765
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 124.2278 - mean_absolute_error: 8.8199 - val_loss: 32.2065 - val_mean_absolute_error: 4.8565
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 108.2709 - mean_absolute_error: 8.5736 - val_loss: 43.7853 - val_mean_absolute_error: 5.2968
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 94.3356 - mean_absolute_error: 8.1290 - val_loss: 52.6277 - val_mean_absolute_error: 5.7012
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 88.4938 - mean_absolute_error: 7.5704 - val_loss: 45.8942 - val_mean_absolute_error: 5.3001
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 66.8139 - mean_absolute_error: 6.3909 - val_loss: 45.1299 - val_mean_absolute_error: 5.2453
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 69.5770 - mean_absolute_error: 6.5539 - val_loss: 32.1798 - val_mean_absolute_error: 4.9551
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.1347 - mean_absolute_error: 5.6295 - val_loss: 46.8900 - val_mean_absolute_error: 5.9301
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.4290 - mean_absolute_error: 6.0237 - val_loss: 54.9724 - val_mean_absolute_error: 6.3414
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 66.4938 - mean_absolute_error: 6.5612 - val_loss: 35.3519 - val_mean_absolute_error: 5.1858
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.3473 - mean_absolute_error: 5.2677 - val_loss: 38.5677 - val_mean_absolute_error: 5.4373
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 49.8075 - mean_absolute_error: 5.2511 - val_loss: 32.4095 - val_mean_absolute_error: 4.8555
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.0277 - mean_absolute_error: 5.0172 - val_loss: 33.0769 - val_mean_absolute_error: 4.8706
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.9292 - mean_absolute_error: 4.2164 - val_loss: 38.8904 - val_mean_absolute_error: 4.9714
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.1018 - mean_absolute_error: 4.4838 - val_loss: 47.5342 - val_mean_absolute_error: 5.4282
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.3705 - mean_absolute_error: 4.2471 - val_loss: 53.7020 - val_mean_absolute_error: 5.7511
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.5353 - mean_absolute_error: 4.1215 - val_loss: 54.4268 - val_mean_absolute_error: 5.7917
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0092 - mean_absolute_error: 3.9398 - val_loss: 76.2497 - val_mean_absolute_error: 7.0325
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.6810 - mean_absolute_error: 4.5451 - val_loss: 62.0330 - val_mean_absolute_error: 6.1763
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.9330 - mean_absolute_error: 3.6508 - val_loss: 57.1732 - val_mean_absolute_error: 5.9295
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 21.1997 - mean_absolute_error: 3.7015 - val_loss: 36.1375 - val_mean_absolute_error: 4.8860
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.2771 - mean_absolute_error: 3.6913 - val_loss: 44.9372 - val_mean_absolute_error: 5.2688
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.8190 - mean_absolute_error: 3.6625 - val_loss: 39.0237 - val_mean_absolute_error: 5.0203
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.7482 - mean_absolute_error: 3.6514 - val_loss: 44.6493 - val_mean_absolute_error: 5.2554
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.8397 - mean_absolute_error: 3.4682 - val_loss: 47.0829 - val_mean_absolute_error: 5.3725
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.6145 - mean_absolute_error: 3.5361 - val_loss: 35.9670 - val_mean_absolute_error: 4.8481
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.7024 - mean_absolute_error: 3.4848 - val_loss: 36.1095 - val_mean_absolute_error: 4.8492
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.0561 - mean_absolute_error: 3.5642 - val_loss: 49.4323 - val_mean_absolute_error: 5.4993

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
data_amazon=pd.read_csv('AMZN.csv')

# %%
df_amazon=pd.DataFrame(data_amazon)
df_amazon.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1  1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 2  1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 3  1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 4  1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
